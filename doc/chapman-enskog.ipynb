# %%
pip install lbmpy[interactive,gpu,doc]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lbmpy[doc,gpu,interactive] in /home/farras_arira/.local/lib/python3.10/site-packages (1.3.3)
# Requirement already satisfied: pystencils<=1.3.3,>=0.4.0 in /home/farras_arira/.local/lib/python3.10/site-packages (from lbmpy[doc,gpu,interactive]) (1.3.3)
# Requirement already satisfied: numpy>=1.11.0 in /home/farras_arira/.local/lib/python3.10/site-packages (from lbmpy[doc,gpu,interactive]) (1.25.2)
# Requirement already satisfied: sympy<=1.11.1,>=1.5.1 in /usr/lib/python3/dist-packages (from lbmpy[doc,gpu,interactive]) (1.9)
# Collecting imageio
#   Downloading imageio-2.34.0-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 KB 3.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cython in /usr/lib/python3/dist-packages (from lbmpy[doc,gpu,interactive]) (0.29.28)
# Collecting pyevtk
#   Downloading pyevtk-1.6.0-py3-none-any.whl (20 kB)
# Collecting scikit-image
#   Downloading scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 6.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from lbmpy[doc,gpu,interactive]) (3.5.1)
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from lbmpy[doc,gpu,interactive]) (1.8.0)
# Collecting ipy-table
#   Downloading ipy_table-1.15.1.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cupy
#   Downloading cupy-13.0.0.tar.gz (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 3.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 6.0 MB/s eta 0:00:0000:0100:01
# Collecting sphinx-autodoc-typehints
#   Downloading sphinx_autodoc_typehints-2.0.0-py3-none-any.whl (19 kB)
# Collecting nbsphinx
#   Downloading nbsphinx-0.9.3-py3-none-any.whl (31 kB)
# Collecting sphinx
#   Downloading sphinx-7.2.6-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 4.2 MB/s eta 0:00:0000:0100:01
# Collecting sphinxcontrib-bibtex
#   Downloading sphinxcontrib_bibtex-2.6.2-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 KB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting pandoc
#   Downloading pandoc-2.3.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /home/farras_arira/.local/lib/python3.10/site-packages (from pystencils<=1.3.3,>=0.4.0->lbmpy[doc,gpu,interactive]) (1.3.2)
# Requirement already satisfied: appdirs in /usr/lib/python3/dist-packages (from pystencils<=1.3.3,>=0.4.0->lbmpy[doc,gpu,interactive]) (1.4.4)
# Requirement already satisfied: fastrlock>=0.5 in /home/farras_arira/.local/lib/python3.10/site-packages (from cupy->lbmpy[doc,gpu,interactive]) (0.8.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/lib/python3/dist-packages (from imageio->lbmpy[doc,gpu,interactive]) (9.0.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->lbmpy[doc,gpu,interactive]) (7.8.0)
# Collecting qtconsole
#   Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 KB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting notebook
#   Downloading notebook-7.1.0-py3-none-any.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 2.8 MB/s eta 0:00:0000:0100:01
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 KB 2.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter->lbmpy[doc,gpu,interactive]) (6.25.2)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.10/dist-packages (from nbsphinx->lbmpy[doc,gpu,interactive]) (5.10.0)
# Collecting docutils
#   Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 KB 3.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from nbsphinx->lbmpy[doc,gpu,interactive]) (3.1.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from nbsphinx->lbmpy[doc,gpu,interactive]) (5.9.2)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->lbmpy[doc,gpu,interactive]) (2.31.0)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.10/dist-packages (from sphinx->lbmpy[doc,gpu,interactive]) (2.12.1)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 KB 2.4 MB/s eta 0:00:00a 0:00:01
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 KB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting imagesize>=1.3
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9
#   Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 KB 2.4 MB/s eta 0:00:0000:01
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 KB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.0 in /usr/lib/python3/dist-packages (from sphinx->lbmpy[doc,gpu,interactive]) (21.3)
# Collecting snowballstemmer>=2.0
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 KB 2.4 MB/s eta 0:00:0000:01
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: Pygments>=2.14 in /usr/local/lib/python3.10/dist-packages (from sphinx->lbmpy[doc,gpu,interactive]) (2.16.1)
# Collecting plumbum
#   Downloading plumbum-1.8.2-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 KB 966.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ply in /usr/lib/python3/dist-packages (from pandoc->lbmpy[doc,gpu,interactive]) (3.11)
# Requirement already satisfied: networkx>=2.8 in /home/farras_arira/.local/lib/python3.10/site-packages (from scikit-image->lbmpy[doc,gpu,interactive]) (3.2.1)
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 KB 2.9 MB/s eta 0:00:00a 0:00:01
# Collecting lazy_loader>=0.3
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Collecting sphinxcontrib-jquery<5,>=4
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting pybtex>=0.24
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 KB 2.4 MB/s eta 0:00:0000:0100:01
# Collecting pybtex-docutils>=1.0.0
#   Downloading pybtex_docutils-1.0.3-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->nbsphinx->lbmpy[doc,gpu,interactive]) (2.1.3)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (3.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (1.5.0)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (5.3.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (0.8.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/lib/python3/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (4.10.0)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (6.0.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (4.19.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (2.18.0)
# Requirement already satisfied: PyYAML>=3.01 in /usr/lib/python3/dist-packages (from pybtex>=0.24->sphinxcontrib-bibtex->lbmpy[doc,gpu,interactive]) (5.4.1)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from pybtex>=0.24->sphinxcontrib-bibtex->lbmpy[doc,gpu,interactive]) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sphinx->lbmpy[doc,gpu,interactive]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sphinx->lbmpy[doc,gpu,interactive]) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sphinx->lbmpy[doc,gpu,interactive]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.25.0->sphinx->lbmpy[doc,gpu,interactive]) (3.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (8.3.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (1.5.8)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (25.1.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (5.9.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.1.6)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.1.4)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (6.3.3)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (8.15.0)
# Collecting jupyterlab-widgets~=3.0.10
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 KB 2.5 MB/s eta 0:00:00a 0:00:01
# Collecting widgetsnbextension~=4.0.10
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter->lbmpy[doc,gpu,interactive]) (3.0.39)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->lbmpy[doc,gpu,interactive]) (2.25.0)
# Collecting jupyterlab<4.2,>=4.1.1
#   Downloading jupyterlab-4.1.1-py3-none-any.whl (11.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 865.1 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->lbmpy[doc,gpu,interactive]) (0.2.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->lbmpy[doc,gpu,interactive]) (2.7.3)
# Collecting qtpy>=2.4.0
#   Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 KB 495.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: webencodings in /usr/lib/python3/dist-packages (from bleach!=5.0.0->nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (0.5.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.7.5)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.19.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.2.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (4.4.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (1.1.3)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (0.10.3)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (0.30.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (2023.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert->jupyter->lbmpy[doc,gpu,interactive]) (3.10.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (1.6.3)
# Requirement already satisfied: jupyter-events>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (0.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (0.17.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (23.1.0)
# Requirement already satisfied: jupyter-server-terminals in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (0.4.4)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (4.0.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (0.17.1)
# Requirement already satisfied: overrides in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (7.4.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->lbmpy[doc,gpu,interactive]) (2.0.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->lbmpy[doc,gpu,interactive]) (2.2.0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->lbmpy[doc,gpu,interactive]) (2.0.4)
# Collecting httpx>=0.25.0
#   Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 KB 745.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->lbmpy[doc,gpu,interactive]) (0.9.14)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->lbmpy[doc,gpu,interactive]) (0.2.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from async-lru>=1.0.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->lbmpy[doc,gpu,interactive]) (4.8.0)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.3-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 KB 835.6 kB/s eta 0:00:00 0:00:01
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 740.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (0.1.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (21.2.0)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (2.4.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->lbmpy[doc,gpu,interactive]) (1.2.0)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (2.4)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (1.5.1)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /usr/lib/python3/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->lbmpy[doc,gpu,interactive]) (1.15.0)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema>=2.6->nbformat->nbsphinx->lbmpy[doc,gpu,interactive]) (1.2.3)
# Building wheels for collected packages: cupy, ipy-table, pandoc
#   Building wheel for cupy (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [63 lines of output]
#       Generating cache key from header files...
#       Cache key (1527 files matching /tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/**): 6d45c70408ab0e010d1f6e69ce6d87e2e3e3b195
#       Clearing directory: /tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/.data
#
#       -------- Configuring Module: cuda --------
#       /tmp/tmpu95i855a/a.cpp:1:10: fatal error: cublas_v2.h: No such file or directory
#           1 | #include <cublas_v2.h>
#             |          ^~~~~~~~~~~~~
#       compilation terminated.
#       command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       /tmp/tmp252l7rb5/a.cpp:2:18: fatal error: cuda_runtime_api.h: No such file or directory
#           2 |         #include <cuda_runtime_api.h>
#             |                  ^~~~~~~~~~~~~~~~~~~~
#       compilation terminated.
#       **************************************************
#       *** WARNING: Cannot check compute capability
#       command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       **************************************************
#
#       ************************************************************
#       * CuPy Configuration Summary                               *
#       ************************************************************
#
#       Build Environment:
#         Include directories: ['/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/libcudacxx', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/thrust', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/cub', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include']
#         Library directories: []
#         nvcc command       : (not found)
#         hipcc command      : (not found)
#
#       Environment Variables:
#         CFLAGS          : (none)
#         LDFLAGS         : (none)
#         LIBRARY_PATH    : (none)
#         CUDA_PATH       : (none)
#         NVCC            : (none)
#         HIPCC           : (none)
#         ROCM_HOME       : (none)
#
#       Modules:
#         cuda      : No
#           -> Include files not found: ['cublas_v2.h', 'cuda.h', 'cuda_profiler_api.h', 'cuda_runtime.h', 'cufft.h', 'curand.h', 'cusparse.h']
#           -> Check your CFLAGS environment variable.
#
#       ERROR: CUDA could not be found on your system.
#
#       HINT: You are trying to build CuPy from source, which is NOT recommended for general use.
#             Please consider using binary packages instead.
#
#       Please refer to the Installation Guide for details:
#       https://docs.cupy.dev/en/stable/install.html
#
#       ************************************************************
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/setup.py", line 93, in <module>
#           ext_modules = cupy_setup_build.get_ext_modules(True, ctx)
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/install/cupy_builder/cupy_setup_build.py", line 473, in get_ext_modules
#           extensions = make_extensions(ctx, compiler, use_cython)
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/install/cupy_builder/cupy_setup_build.py", line 328, in make_extensions
#           raise Exception('Your CUDA environment is invalid. '
#       Exception: Your CUDA environment is invalid. Please check above error log.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for cupy
#   Running setup.py clean for cupy
#   error: subprocess-exited-with-error
#
#   × python setup.py clean did not run successfully.
#   │ exit code: 1
#   ╰─> [63 lines of output]
#       Generating cache key from header files...
#       Cache key (1527 files matching /tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/**): 6d45c70408ab0e010d1f6e69ce6d87e2e3e3b195
#       Clearing directory: /tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/.data
#
#       -------- Configuring Module: cuda --------
#       /tmp/tmp5vu6ppo4/a.cpp:1:10: fatal error: cublas_v2.h: No such file or directory
#           1 | #include <cublas_v2.h>
#             |          ^~~~~~~~~~~~~
#       compilation terminated.
#       command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       /tmp/tmp88cb06jx/a.cpp:2:18: fatal error: cuda_runtime_api.h: No such file or directory
#           2 |         #include <cuda_runtime_api.h>
#             |                  ^~~~~~~~~~~~~~~~~~~~
#       compilation terminated.
#       **************************************************
#       *** WARNING: Cannot check compute capability
#       command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       **************************************************
#
#       ************************************************************
#       * CuPy Configuration Summary                               *
#       ************************************************************
#
#       Build Environment:
#         Include directories: ['/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/libcudacxx', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/thrust', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/cub', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include']
#         Library directories: []
#         nvcc command       : (not found)
#         hipcc command      : (not found)
#
#       Environment Variables:
#         CFLAGS          : (none)
#         LDFLAGS         : (none)
#         LIBRARY_PATH    : (none)
#         CUDA_PATH       : (none)
#         NVCC            : (none)
#         HIPCC           : (none)
#         ROCM_HOME       : (none)
#
#       Modules:
#         cuda      : No
#           -> Include files not found: ['cublas_v2.h', 'cuda.h', 'cuda_profiler_api.h', 'cuda_runtime.h', 'cufft.h', 'curand.h', 'cusparse.h']
#           -> Check your CFLAGS environment variable.
#
#       ERROR: CUDA could not be found on your system.
#
#       HINT: You are trying to build CuPy from source, which is NOT recommended for general use.
#             Please consider using binary packages instead.
#
#       Please refer to the Installation Guide for details:
#       https://docs.cupy.dev/en/stable/install.html
#
#       ************************************************************
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/setup.py", line 93, in <module>
#           ext_modules = cupy_setup_build.get_ext_modules(True, ctx)
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/install/cupy_builder/cupy_setup_build.py", line 473, in get_ext_modules
#           extensions = make_extensions(ctx, compiler, use_cython)
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/install/cupy_builder/cupy_setup_build.py", line 328, in make_extensions
#           raise Exception('Your CUDA environment is invalid. '
#       Exception: Your CUDA environment is invalid. Please check above error log.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for cupy
#   Building wheel for ipy-table (setup.py) ... done
#   Created wheel for ipy-table: filename=ipy_table-1.15.1-py3-none-any.whl size=18761 sha256=66ad352ee8d7f41103131b284f70b57a16da3cd919e69acb24e478a80381bc75
#   Stored in directory: /home/farras_arira/.cache/pip/wheels/e9/5c/49/5e9d7924df16a11e23bcdcca4eab6105c2aaec80f72c66c641
#   Building wheel for pandoc (setup.py) ... done
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33286 sha256=592d92ad70b4feb3b92e405cac695e100c181f7517b49c6edea7be0b8fba839d
#   Stored in directory: /home/farras_arira/.cache/pip/wheels/76/27/c2/c26175310aadcb8741b77657a1bb49c50cc7d4cdbf9eee0005
# Successfully built ipy-table pandoc
# Failed to build cupy
# Installing collected packages: snowballstemmer, ipy-table, widgetsnbextension, tifffile, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, qtpy, pyevtk, plumbum, lazy_loader, latexcodec, jupyterlab-widgets, imagesize, imageio, h11, docutils, cupy, alabaster, sphinx, scikit-image, pybtex, pandoc, httpcore, sphinxcontrib-jquery, sphinx-autodoc-typehints, pybtex-docutils, httpx, sphinxcontrib-bibtex, sphinx-rtd-theme, ipywidgets, qtconsole, jupyter-console, nbsphinx, jupyterlab, notebook, jupyter
#   Running setup.py install for cupy ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for cupy did not run successfully.
#   │ exit code: 1
#   ╰─> [63 lines of output]
#       Generating cache key from header files...
#       Cache key (1527 files matching /tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/**): 6d45c70408ab0e010d1f6e69ce6d87e2e3e3b195
#       Clearing directory: /tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/.data
#
#       -------- Configuring Module: cuda --------
#       /tmp/tmpitsu6yd4/a.cpp:1:10: fatal error: cublas_v2.h: No such file or directory
#           1 | #include <cublas_v2.h>
#             |          ^~~~~~~~~~~~~
#       compilation terminated.
#       command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       /tmp/tmpr10j4q_4/a.cpp:2:18: fatal error: cuda_runtime_api.h: No such file or directory
#           2 |         #include <cuda_runtime_api.h>
#             |                  ^~~~~~~~~~~~~~~~~~~~
#       compilation terminated.
#       **************************************************
#       *** WARNING: Cannot check compute capability
#       command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       **************************************************
#
#       ************************************************************
#       * CuPy Configuration Summary                               *
#       ************************************************************
#
#       Build Environment:
#         Include directories: ['/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/libcudacxx', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/thrust', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include/cupy/_cccl/cub', '/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/cupy/_core/include']
#         Library directories: []
#         nvcc command       : (not found)
#         hipcc command      : (not found)
#
#       Environment Variables:
#         CFLAGS          : (none)
#         LDFLAGS         : (none)
#         LIBRARY_PATH    : (none)
#         CUDA_PATH       : (none)
#         NVCC            : (none)
#         HIPCC           : (none)
#         ROCM_HOME       : (none)
#
#       Modules:
#         cuda      : No
#           -> Include files not found: ['cublas_v2.h', 'cuda.h', 'cuda_profiler_api.h', 'cuda_runtime.h', 'cufft.h', 'curand.h', 'cusparse.h']
#           -> Check your CFLAGS environment variable.
#
#       ERROR: CUDA could not be found on your system.
#
#       HINT: You are trying to build CuPy from source, which is NOT recommended for general use.
#             Please consider using binary packages instead.
#
#       Please refer to the Installation Guide for details:
#       https://docs.cupy.dev/en/stable/install.html
#
#       ************************************************************
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/setup.py", line 93, in <module>
#           ext_modules = cupy_setup_build.get_ext_modules(True, ctx)
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/install/cupy_builder/cupy_setup_build.py", line 473, in get_ext_modules
#           extensions = make_extensions(ctx, compiler, use_cython)
#         File "/tmp/pip-install-w7fq33j5/cupy_9e6a05fac51941369498000e416d0451/install/cupy_builder/cupy_setup_build.py", line 328, in make_extensions
#           raise Exception('Your CUDA environment is invalid. '
#       Exception: Your CUDA environment is invalid. Please check above error log.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> cupy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# Note: you may need to restart the kernel to use updated packages.

# %%
from lbmpy.session import *
from lbmpy.chapman_enskog import ChapmanEnskogAnalysis
sp.init_printing()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from lbmpy.session import *
#       2 from lbmpy.chapman_enskog import ChapmanEnskogAnalysis
#       3 sp.init_printing()
#
# File ~/.local/lib/python3.10/site-packages/lbmpy/session.py:14
#      12 from lbmpy.lbstep import LatticeBoltzmannStep
#      13 from lbmpy.macroscopic_value_kernels import pdf_initialization_assignments
# ---> 14 from lbmpy.parameterization import ScalingWidget
#      15 import lbmpy.plot as plt
#      16 from lbmpy.postprocessing import *
#
# File ~/.local/lib/python3.10/site-packages/lbmpy/parameterization.py:3
#       1 from collections import namedtuple
# ----> 3 import ipywidgets.widgets as widgets
#       4 from IPython.display import display
#       5 from ipywidgets.widgets import BoundedFloatText, Button, FloatText, HBox, Label, Select, VBox
#
# ModuleNotFoundError: No module named 'ipywidgets'
